# %%
#Importing the required libraries
import json


#opening and reading the slurs words file and the sample tweets json file.
with open("racial_slurs.txt",'r') as slur_words, open('smaple_tweets.json','r') as sample_tweets:
    words = slur_words.read().splitlines()
    tweets = json.load(sample_tweets)


#empty list for stroing the tweets with racial slurs
profane_tweets = []


#finding racial slurs in the sample tweets
for j in tweets['sampleTweets']:
    profane_count = (sum(j.lower().count(i) for i in words))
    profane_tweets.append([j, profane_count])


#Cacluting the degree of profanity
# degree pf profanity = no. of racial slurs found in the tweet /s word count of the tweet
for i in profane_tweets:
    score = (i[1]/len(i[0]))
    if score == 0.0:
        degree_of_profanity = "Not Profane"
    elif score > 0.0  and score < 0.019:
        degree_of_profanity = 'Slightly Profane'
    elif score > 0.019 and score < 0.045:
        degree_of_profanity = 'Highly Profane'
    else:
        degree_of_profanity = 'Exteremely Profane'
    print("Tweet:",i[0],": \n Score of profanity: ",score,"\n","Degree of Profanity: ",degree_of_profanity)
    print("\n\n")
# Out:
# Tweet: Your not much diff from natives when it comes to drinking ... Except your clean. :
#  Score of profanity:  0.0125
#  Degree of Profanity:  Slightly Profane
#
#
#
# Tweet: if you're having a rough time, just remember: god gives his hardest battles to the people he just doesn't like very much :
#  Score of profanity:  0.0
#  Degree of Profanity:  Not Profane
#
#
#
# Tweet: Dad cuts up Water Melon for my lunch, looks at me and says ‘Here’s your nigger food’. #Hahaha #LoveYou :
#  Score of profanity:  0.00980392156862745
#  Degree of Profanity:  Slightly Profane
#
#
#
# Tweet: My heart goes out to the Malaysian people. This is such a tragedy. Words can't express how sad it is. I wish we could just have peace. #MH17 :
#  Score of profanity:  0.0
#  Degree of Profanity:  Not Profane
#
#
#
# Tweet: This group of chinks on the bus f***ing wreak I’m gagging and covering my face in my shirt. :
#  Score of profanity:  0.01098901098901099
#  Degree of Profanity:  Slightly Profane
#
#
#
# Tweet: I think I hate cardio as much as I hate paki’s. :
#  Score of profanity:  0.02127659574468085
#  Degree of Profanity:  Highly Profane
#
#
#
# Tweet: fUcK yOu In ThE aSs PuNk wHiTe BoY :
#  Score of profanity:  0.029411764705882353
#  Degree of Profanity:  Highly Profane
#
#
#
# Tweet: I just attended a group wedding for people who have been waiting years to get married. Just wow. #equality #lovewins :
#  Score of profanity:  0.0
#  Degree of Profanity:  Not Profane
#
#
#
# Tweet: ATLEAST I DON'T ROB PEOPLE AND WEAR METAL ON MY TEETH. KEEP 'EM COMING NIGGER THIS IS FUN :
#  Score of profanity:  0.011235955056179775
#  Degree of Profanity:  Slightly Profane
#
#
#
# Tweet: Man these pakis need to leave the gym it’s starting to smell like stale Burger King in here. :
#  Score of profanity:  0.010869565217391304
#  Degree of Profanity:  Slightly Profane
#
#
#
# Tweet: Drunk natives brushing his pony tail on me #help #gross :
#  Score of profanity:  0.01818181818181818
#  Degree of Profanity:  Slightly Profane
#
#
#
# Tweet: OF COURSE...THE NATIVES nigger ARE GOING TO THE LIQOUR STORE. #wHATASURPRISE :
#  Score of profanity:  0.02631578947368421
#  Degree of Profanity:  Highly Profane
#
#
#
# Tweet: My #SocialMedia seniors book in 1200+ stores in Canada, next to #1 best seller by Harper Lee. TY @ShopprsDrugMart :
#  Score of profanity:  0.0
#  Degree of Profanity:  Not Profane
#
#
#
# Tweet: When my friends make me sit next to the nigger in the theater ... #thanksbitches :
#  Score of profanity:  0.0125
#  Degree of Profanity:  Slightly Profane
#
#
#
# Tweet: Fucking paki shops that charge you for cash withdrawls or paying by card need nuked :
#  Score of profanity:  0.012048192771084338
#  Degree of Profanity:  Slightly Profane
#
#
#
# Tweet: Getting older. I used to be able to run a 4-minute mile, bench press 380 pounds, and tell the truth. :
#  Score of profanity:  0.0
#  Degree of Profanity:  Not Profane
#
#
#
# Tweet: MY MOM CALLS THE DUCK FACE NIGGER LIPS. NOT SURE IF RACIST OR FUNNY :
#  Score of profanity:  0.014925373134328358
#  Degree of Profanity:  Slightly Profane
#
#
#
# Tweet: Dear waiter: about the dirty rag on your head to hide your dreds: YOU ARE WHITE. Dreds on a white boy just makes you look homeless :
#  Score of profanity:  0.007692307692307693
#  Degree of Profanity:  Slightly Profane
#
#
#
# Tweet: Women get to smell like real things (vanilla, lavender) but men have to smell like concepts. What the fuck is 'cool sport rush' :
#  Score of profanity:  0.0
#  Degree of Profanity:  Not Profane
#
#
#
# Tweet: THE ONLY TIME I WILL DRIVE SOMEWHERE LOOKING LIKE WHITE TRASH IS WHEN I AM GOING TO THE REZ. HELPS ME FIT IN :
#  Score of profanity:  0.009259259259259259
#  Degree of Profanity:  Slightly Profane
